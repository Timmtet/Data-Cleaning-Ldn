# %% [markdown]
# <h1 style='background-color: Indigo; padding: 10px; color: white; text-align: center;'>DATA CLEANING </h1>

# %% [markdown]
# First things first, we will import all the required packages

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# We will start by cleaning all the sales data for each of the three websites

# %% [markdown]
# <h1 style='background-color: Indigo; padding: 10px; color: white'> Sales data </h1>

# %% [markdown]
# We will import the sales data for the three websites

# %%
# Rightmove
rm = pd.read_csv('RightMove_Sales_data.csv')

# On the Market
om = pd.read_csv('OnTheMarket_Sales_data.csv')

#Zoopla
zp = pd.read_csv('Zoopla_Sales_data.csv')

# %% [markdown]
# We will remove the unwanted column 'Unnamed from all the datasets'

# %%
# Rightmove
rm = rm.drop('Unnamed: 0', axis=1)

# On the Market
om = om.drop('Unnamed: 0', axis=1)

#Zoopla
zp = zp.drop('Unnamed: 0', axis=1)

# %% [markdown]
# # Rightmove

# %% [markdown]
# Now we will assess and clean the sales data for rightmove

# %% [markdown]
# ## a) Data Assesment

# %%
rm.head(10)
# Out:
#     Unique_Id Location Tansaction_Type Property_Type
# 0  BR1S0000RM      BR1           Sales      Terraced  \
# 1  BR1S0001RM      BR1           Sales      Detached
# 2  BR1S0002RM      BR1           Sales      Detached
# 3  BR1S0003RM      BR1           Sales      Detached
# 4  BR1S0004RM      BR1           Sales         House
# 5  BR1S0005RM      BR1           Sales      Detached
# 6  BR1S0006RM      BR1           Sales      Detached
# 7  BR1S0007RM      BR1           Sales      Detached
# 8  BR1S0008RM      BR1           Sales      Detached
# 9  BR1S0009RM      BR1           Sales         House
#
#                                              Address  Bedrooms  Bathrooms
# 0                          Palace View, Bromley, BR1         3          1  \
# 1  Provident House, 122-126 High Street, Bromley BR1         6          7
# 2                           Woodlands Close, Bromley         5          5
# 3                       Sundridge Avenue Bromley BR1         6          3
# ...

# %%
# Checking the shape of the data
rm.shape
# Out:
# (49641, 13)

# %%
# Checking the data distribution
rm.describe()
# Out:
#            Bedrooms     Bathrooms
# count  49641.000000  49641.000000
# mean       2.505933      1.648617
# std        1.316835      1.138742
# min        1.000000      1.000000
# 25%        2.000000      1.000000
# 50%        2.000000      1.000000
# 75%        3.000000      2.000000
# max       28.000000    144.000000

# %%
# Assessing the data types
rm.dtypes
# Out:
# Unique_Id          object
# Location           object
# Tansaction_Type    object
# Property_Type      object
# Address            object
# Bedrooms            int64
# Bathrooms           int64
# Price              object
# Description        object
# Listing_Date       object
# Agent              object
# Listing_Source     object
# listing_URL        object
# dtype: object

# %% [markdown]
# ## b) Dealing with nulls

# %%
rm.isnull().sum()
# Out:
# Unique_Id            0
# Location             0
# Tansaction_Type      0
# Property_Type        1
# Address              0
# Bedrooms             0
# Bathrooms            0
# Price              293
# Description          4
# Listing_Date       100
# Agent                0
# Listing_Source       0
# listing_URL          0
# dtype: int64

# %% [markdown]
# Three of the column has nulls

# %% [markdown]
# ### i) Dealing with nulls in the Property_Type column

# %%
# For the Property_type column
rm[rm['Property_Type'].isnull()]
# Out:
#            Unique_Id Location Tansaction_Type Property_Type
# 21919  N3S00021919RM       N3           Sales           NaN  \
#
#                                 Address  Bedrooms  Bathrooms     Price
# 21919  Edge Hill Avenue, London, N3 3AY         2          2  £405,000  \
#
#                                              Description         Listing_Date
# 21919  New beginnings in North LondonLocated in Finch...  Added on 03/03/2023  \
#
#                                                  Agent Listing_Source
# 21919  Added on 03/02/2023 by Martyn Gerrard, Finchley      RightMove  \
#
#                                              listing_URL
# 21919  https://www.rightmove.co.uk/property-for-sale/...

# %% [markdown]
# We will replace the null with 'Not listed'

# %%
rm['Property_Type'].fillna('Not listed', inplace=True)

# %% [markdown]
# ### ii) Dealing with nulls in the Price column

# %%
# For the Price column
rm[rm['Price'].isnull()].head()
# Out:
#         Unique_Id Location Tansaction_Type   Property_Type
# 648  BR3S000648RM      BR3           Sales        Detached  \
# 682  BR3S000682RM      BR3           Sales        Detached
# 684  BR3S000684RM      BR3           Sales        Terraced
# 686  BR3S000686RM      BR3           Sales   Semi-Detached
# 691  BR3S000691RM      BR3           Sales  End of Terrace
#
#                                              Address  Bedrooms  Bathrooms
# 648                       Edgefield Close, Beckenham         5          2  \
# 682  Langley Court, 11 Roman Way, Beckenham, BR3 3FH         3          1
# 684                   St. Martins Lane Beckenham BR3         4          2
# 686                        Roman Way, Beckenham, BR3         4          2
# 691                   Albemarle Road, Beckenham, BR3         3          2
#
#     Price                                        Description
# 648   NaN  Boasting a peaceful gated cul-de-sac position,...  \
# ...

# %% [markdown]
# We will replace the null with 'Not listed'

# %%
rm['Price'].fillna('Not listed', inplace=True)

# %% [markdown]
# ### iii) Dealing with nulls in the Listing_Date column

# %%
# For the Listing Date column
rm[rm['Listing_Date'].isnull()].head()
# Out:
#           Unique_Id Location Tansaction_Type  Property_Type
# 1        BR1S0001RM      BR1           Sales       Detached  \
# 148    BR1S000148RM      BR1           Sales  Land for sale
# 603    BR2S000603RM      BR2           Sales           Flat
# 1034  BR5S0001034RM      BR5           Sales  Plot for sale
# 1277  BR6S0001277RM      BR6           Sales  Plot for sale
#
#                                                 Address  Bedrooms  Bathrooms
# 1     Provident House, 122-126 High Street, Bromley BR1         6          7  \
# 148                    College Road, Bromley, Kent, BR1         2          2
# 603                        Homesdale Road, Bromley, BR2         1          1
# 1034                              Rosecroft Social Club         5          3
# 1277               Land At Charterhouse Road, Orpington         4          4
#
#            Price                                        Description
# 1     £5,750,000  Extremely rare opportunity to purchase this tr...  \
# ...

# %% [markdown]
# We will replace the null with 'Not listed'

# %%
rm['Listing_Date'].fillna('Not listed', inplace=True)

# %% [markdown]
# ### iv) Dealing with nulls in the Listing_Date column

# %%
# For the Description column
rm[rm['Description'].isnull()].head()
# Out:
#            Unique_Id Location Tansaction_Type Property_Type
# 45663  W2S00045663RM       W2           Sales          Flat  \
# 46045  W2S00046045RM       W2           Sales     Apartment
# 46056  W2S00046056RM       W2           Sales          Flat
# 46127  W2S00046127RM       W2           Sales          Flat
#
#                                                  Address  Bedrooms  Bathrooms
# 45663   Flat 9, 69-71 Gloucester Terrace, London, W2 3DH         1          3  \
# 46045                         Monmouth Place, London, W2         1          1
# 46056  Flat 15, 69-71 Gloucester Terrace, London, W2 3DH         1          2
# 46127   Flat 9, 69-71 Gloucester Terrace, London, W2 3DH         1          1
#
#           Price Description           Listing_Date
# 45663  £240,000         NaN    Added on 05/05/2023  \
# 46045  £940,000         NaN  Reduced on 23/03/2023
# 46056  £240,000         NaN    Added on 05/05/2023
# 46127  £240,000         NaN    Added on 05/05/2023
#
# ...

# %% [markdown]
# We will replace the null with 'Not listed'

# %%
rm['Description'].fillna('Not listed', inplace=True)

# %%
rm.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        0
# Listing_Date       0
# Agent              0
# Listing_Source     0
# listing_URL        0
# dtype: int64

# %% [markdown]
# All the nulls have been succesfully dealt with.

# %% [markdown]
# ## c) Data Cleaning

# %%
rm.head()
# Out:
#     Unique_Id Location Tansaction_Type Property_Type
# 0  BR1S0000RM      BR1           Sales      Terraced  \
# 1  BR1S0001RM      BR1           Sales      Detached
# 2  BR1S0002RM      BR1           Sales      Detached
# 3  BR1S0003RM      BR1           Sales      Detached
# 4  BR1S0004RM      BR1           Sales         House
#
#                                              Address  Bedrooms  Bathrooms
# 0                          Palace View, Bromley, BR1         3          1  \
# 1  Provident House, 122-126 High Street, Bromley BR1         6          7
# 2                           Woodlands Close, Bromley         5          5
# 3                       Sundridge Avenue Bromley BR1         6          3
# 4               Mavelstone Close, Bromley, Kent, BR1         8          3
#
#         Price                                        Description
# 0    £745,000  A fantastic opportunity to purchase this mid t...  \
# 1  £5,750,000  Extremely rare opportunity to purchase this tr...
# ...

# %% [markdown]
# ### i) Cleaning the Listing_Date column

# %% [markdown]
# Now, we will modify the Listed date column

# %%
# Removing the 'Added on' from the values
rm['Listing_Date'] = rm['Listing_Date'].str.replace('Added on ', '', regex=True)
rm['Listing_Date'] = rm['Listing_Date'].str.replace('Reduced on ', '', regex=True)

# %%
rm.head()
# Out:
#     Unique_Id Location Tansaction_Type Property_Type
# 0  BR1S0000RM      BR1           Sales      Terraced  \
# 1  BR1S0001RM      BR1           Sales      Detached
# 2  BR1S0002RM      BR1           Sales      Detached
# 3  BR1S0003RM      BR1           Sales      Detached
# 4  BR1S0004RM      BR1           Sales         House
#
#                                              Address  Bedrooms  Bathrooms
# 0                          Palace View, Bromley, BR1         3          1  \
# 1  Provident House, 122-126 High Street, Bromley BR1         6          7
# 2                           Woodlands Close, Bromley         5          5
# 3                       Sundridge Avenue Bromley BR1         6          3
# 4               Mavelstone Close, Bromley, Kent, BR1         8          3
#
#         Price                                        Description Listing_Date
# 0    £745,000  A fantastic opportunity to purchase this mid t...   27/03/2023  \
# ...

# %% [markdown]
# Convert any non-date values in the Listed_Date column to 'Not Listed'

# %%
# Convert the column to string type
rm['Listing_Date'] = rm['Listing_Date'].astype(str)

# Check if the value matches the date format
mask = rm['Listing_Date'].str.match(r'\d{2}/\d{2}/\d{4}')

# Replace non-matching values with 'Not Listed'
rm.loc[~mask, 'Listing_Date'] = 'Not Listed'

# %%
rm.Listing_Date.value_counts()
# Out:
# Listing_Date
# Not Listed    6252
# 03/05/2023    1211
# 02/05/2023    1154
# 28/04/2023     981
# 24/04/2023     929
#               ...
# 26/09/2019       1
# 01/11/2020       1
# 30/09/2020       1
# 26/12/2018       1
# 16/06/2021       1
# Name: count, Length: 929, dtype: int64

# %% [markdown]
# ### ii) Cleaning the Agent column

# %% [markdown]
# Modifying the Agent column

# %%
# Removing all strings before the word 'by'
try:
    rm['Agent'] = rm['Agent'].str.split('by', n=1).str[1].str.strip()
except ValueError:
    pass

# %%
rm.head()
# Out:
#     Unique_Id Location Tansaction_Type Property_Type
# 0  BR1S0000RM      BR1           Sales      Terraced  \
# 1  BR1S0001RM      BR1           Sales      Detached
# 2  BR1S0002RM      BR1           Sales      Detached
# 3  BR1S0003RM      BR1           Sales      Detached
# 4  BR1S0004RM      BR1           Sales         House
#
#                                              Address  Bedrooms  Bathrooms
# 0                          Palace View, Bromley, BR1         3          1  \
# 1  Provident House, 122-126 High Street, Bromley BR1         6          7
# 2                           Woodlands Close, Bromley         5          5
# 3                       Sundridge Avenue Bromley BR1         6          3
# 4               Mavelstone Close, Bromley, Kent, BR1         8          3
#
#         Price                                        Description Listing_Date
# 0    £745,000  A fantastic opportunity to purchase this mid t...   27/03/2023  \
# ...

# %%
# Replace all nulls with 'Not listed'
rm['Agent'].fillna('Not listed', inplace=True)

# %% [markdown]
# # On the Market

# %% [markdown]
# Now we will clean the sales data for On the Market

# %% [markdown]
# ## a) Data Assessment

# %%
om.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1S00001OM      BR1           Sales  \
# 1  BR1S00001OM      BR1           Sales
# 2  BR1S00001OM      BR1           Sales
# 3  BR1S00001OM      BR1           Sales
# 4  BR1S00001OM      BR1           Sales
#
#                             Property_Type                             Address
# 0       3 bedroom terraced house for sale         Parkside Avenue Bromley BR1  \
# 1       2 bedroom terraced house for sale    Foxbury Road, Bromley, Kent, BR1
# 2  3 bedroom semi-detached house for sale  Bishops Avenue, Bromley, Kent, BR1
# 3       2 bedroom terraced house for sale              Gladwell Road, Bromley
# 4            1 bedroom apartment for sale     Liddon Road, Bromley, Kent, BR1
#
#   Bedrooms  Bathrooms     Price
# 0        3        1.0  £550,000  \
# 1        2        1.0  £525,000
# 2        3        1.0  £575,000
# 3        2        1.0  £475,000
# 4        1        1.0  £250,000
#
# ...

# %%
# Checking the shape of the Dataset
om.shape
# Out:
# (14790, 14)

# %%
# Checking the datatype
om.dtypes
# Out:
# Unique_Id           object
# Location            object
# Tansaction_Type     object
# Property_Type       object
# Address             object
# Bedrooms            object
# Bathrooms          float64
# Price               object
# Description         object
# Listing_Date        object
# Agent               object
# Listing_Source      object
# listing_URL         object
# Current_date        object
# dtype: object

# %%
# Checking the shape of the Dataset
om.describe()
# Out:
#           Bathrooms
# count  13946.000000
# mean       1.643769
# std        0.965680
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       15.000000

# %% [markdown]
# ## b) Dealing with nulls

# %%
om.isnull().sum()
# Out:
# Unique_Id              0
# Location               0
# Tansaction_Type        0
# Property_Type          0
# Address                0
# Bedrooms             107
# Bathrooms            844
# Price                  0
# Description            0
# Listing_Date           0
# Agent              10216
# Listing_Source         0
# listing_URL            0
# Current_date           0
# dtype: int64

# %% [markdown]
# Now, we will replace all the nulls with 'Not listed'

# %%
# Replacing nulls in the Bedroom column with 'Not Listed'
om['Bedrooms'].fillna('Not listed', inplace=True)

# Replacing nulls in the Bathrooms column with 'Not Listed'
om['Bathrooms'].fillna('Not listed', inplace=True)

# Replacing nulls in the Agent column with 'Not Listed'
om['Agent'].fillna('Not listed', inplace=True)

# %%
om.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        0
# Listing_Date       0
# Agent              0
# Listing_Source     0
# listing_URL        0
# Current_date       0
# dtype: int64

# %% [markdown]
# All nulls have been succesfully dealt with

# %% [markdown]
# ## c) Data Cleaning

# %%
om.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1S00001OM      BR1           Sales  \
# 1  BR1S00001OM      BR1           Sales
# 2  BR1S00001OM      BR1           Sales
# 3  BR1S00001OM      BR1           Sales
# 4  BR1S00001OM      BR1           Sales
#
#                             Property_Type                             Address
# 0       3 bedroom terraced house for sale         Parkside Avenue Bromley BR1  \
# 1       2 bedroom terraced house for sale    Foxbury Road, Bromley, Kent, BR1
# 2  3 bedroom semi-detached house for sale  Bishops Avenue, Bromley, Kent, BR1
# 3       2 bedroom terraced house for sale              Gladwell Road, Bromley
# 4            1 bedroom apartment for sale     Liddon Road, Bromley, Kent, BR1
#
#   Bedrooms Bathrooms     Price
# 0        3       1.0  £550,000  \
# 1        2       1.0  £525,000
# 2        3       1.0  £575,000
# 3        2       1.0  £475,000
# 4        1       1.0  £250,000
#
# ...

# %% [markdown]
# ### i) Cleaning the Listing_Date Column

# %% [markdown]
# Here are the values available in the Listing_Date

# %%
om.Listing_Date.value_counts()
# Out:
# Listing_Date
# OnTheMarket > 14 days    11559
# OnTheMarket < 14 days      869
# OnTheMarket < 7 days       823
# OnTheMarket yesterday      423
# Reduced < 7 days           423
# Reduced < 14 days          385
# Reduced yesterday          160
# OnTheMarket today          100
# Reduced today               44
# Reduced > 14 days            4
# Name: count, dtype: int64

# %% [markdown]
# To ensure uniformity with the dataset from other websites, we need to convert the values into a Date datatype. We will accomplish this by utilizing the 'Current_date' column, which represents the date the data was web scraped, and the 'Listing_date' column to compute a new column that will serve as our standardized listing date.
#
# E.g If current date = 15/05/2023 and Listing date = OnTheMarket > 14 days. Date_main will be  01/05/2023
#
# If current date = 15/05/2023 and Listing date = OnTheMarket today. Date_main will be 15/05/2023

# %%
# Convert 'Current_date' column to datetime type
om['Current_date'] = pd.to_datetime(om['Current_date'], format='%d/%m/%Y')

# Calculate the new 'Date_main' column based on different conditions
om['Date_main'] = om.apply(
    lambda row: (
        (row['Current_date']).strftime('%d/%m/%Y')
        if row['Listing_Date'] in ['Reduced today', 'OnTheMarket today']
        else (row['Current_date'] - timedelta(days=1)).strftime('%d/%m/%Y')
        if row['Listing_Date'] in ['Reduced yesterday', 'OnTheMarket yesterday']
        else (row['Current_date'] - timedelta(days=14)).strftime('%d/%m/%Y')  # > (current date - 14 days)
        if row['Listing_Date'] in ['OnTheMarket > 14 days', 'Reduced > 14 days']
        else (row['Current_date'] - timedelta(days=14)).strftime('%d/%m/%Y')  # < (current date - 14 days)
        if row['Listing_Date'] in ['OnTheMarket < 14 days', 'Reduced < 14 days']
        else (row['Current_date'] - timedelta(days=7)).strftime('%d/%m/%Y')  # < (current date - 7 days)
        if row['Listing_Date'] in ['OnTheMarket < 7 days', 'Reduced < 7 days']
        else None  # Add any other conditions or default value if needed
    ),
    axis=1
)

# Convert the column to datetime type
om['Date_main'] = pd.to_datetime(om['Date_main'], format='%d/%m/%Y')

# Convert the values to the desired format
om['Date_main'] = om['Date_main'].dt.strftime('%d/%m/%Y')

# %%
om.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1S00001OM      BR1           Sales  \
# 1  BR1S00001OM      BR1           Sales
# 2  BR1S00001OM      BR1           Sales
# 3  BR1S00001OM      BR1           Sales
# 4  BR1S00001OM      BR1           Sales
#
#                             Property_Type                             Address
# 0       3 bedroom terraced house for sale         Parkside Avenue Bromley BR1  \
# 1       2 bedroom terraced house for sale    Foxbury Road, Bromley, Kent, BR1
# 2  3 bedroom semi-detached house for sale  Bishops Avenue, Bromley, Kent, BR1
# 3       2 bedroom terraced house for sale              Gladwell Road, Bromley
# 4            1 bedroom apartment for sale     Liddon Road, Bromley, Kent, BR1
#
#   Bedrooms Bathrooms     Price
# 0        3       1.0  £550,000  \
# 1        2       1.0  £525,000
# 2        3       1.0  £575,000
# 3        2       1.0  £475,000
# 4        1       1.0  £250,000
#
# ...

# %%
om.shape
# Out:
# (14790, 15)

# %%
# Drop the 'Current_date' and 'Listing_Date' columns
om.drop(['Current_date', 'Listing_Date'], axis=1, inplace=True)

# %% [markdown]
# For uniformity with the datsets from other websites, the Date_main column will be renamed as Listing_Date

# %%
# Rename the 'Date_main' column to 'Listing_Date'
om.rename(columns={'Date_main': 'Listing_Date'}, inplace=True)

# %%
om.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1S00001OM      BR1           Sales  \
# 1  BR1S00001OM      BR1           Sales
# 2  BR1S00001OM      BR1           Sales
# 3  BR1S00001OM      BR1           Sales
# 4  BR1S00001OM      BR1           Sales
#
#                             Property_Type                             Address
# 0       3 bedroom terraced house for sale         Parkside Avenue Bromley BR1  \
# 1       2 bedroom terraced house for sale    Foxbury Road, Bromley, Kent, BR1
# 2  3 bedroom semi-detached house for sale  Bishops Avenue, Bromley, Kent, BR1
# 3       2 bedroom terraced house for sale              Gladwell Road, Bromley
# 4            1 bedroom apartment for sale     Liddon Road, Bromley, Kent, BR1
#
#   Bedrooms Bathrooms     Price
# 0        3       1.0  £550,000  \
# 1        2       1.0  £525,000
# 2        3       1.0  £575,000
# 3        2       1.0  £475,000
# 4        1       1.0  £250,000
#
#                                          Description
# ...

# %% [markdown]
# Now we will move the new listed date column to it's right position

# %%
# Get the column names
columns = om.columns.tolist()

# Specify the position where you want to move the column (e.g., from 4th position to 1st position)
from_position = 12
to_position = 9

# Move the column to the desired position
columns.insert(to_position, columns.pop(from_position))

# Reassign the columns in the DataFrame with the updated order
om = om[columns]

# %%
om.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1S00001OM      BR1           Sales  \
# 1  BR1S00001OM      BR1           Sales
# 2  BR1S00001OM      BR1           Sales
# 3  BR1S00001OM      BR1           Sales
# 4  BR1S00001OM      BR1           Sales
#
#                             Property_Type                             Address
# 0       3 bedroom terraced house for sale         Parkside Avenue Bromley BR1  \
# 1       2 bedroom terraced house for sale    Foxbury Road, Bromley, Kent, BR1
# 2  3 bedroom semi-detached house for sale  Bishops Avenue, Bromley, Kent, BR1
# 3       2 bedroom terraced house for sale              Gladwell Road, Bromley
# 4            1 bedroom apartment for sale     Liddon Road, Bromley, Kent, BR1
#
#   Bedrooms Bathrooms     Price
# 0        3       1.0  £550,000  \
# 1        2       1.0  £525,000
# 2        3       1.0  £575,000
# 3        2       1.0  £475,000
# 4        1       1.0  £250,000
#
# ...

# %% [markdown]
# ### ii) Cleaning the Bathrooms column

# %%
# Strip ".0" from float values while preserving "Not Listed"
om['Bathrooms'] = om['Bathrooms'].apply(lambda x: str(x).rstrip('.0') if x != 'Not Listed' else x)

# %%
om
# Out:
#           Unique_Id Location Tansaction_Type
# 0       BR1S00001OM      BR1           Sales  \
# 1       BR1S00001OM      BR1           Sales
# 2       BR1S00001OM      BR1           Sales
# 3       BR1S00001OM      BR1           Sales
# 4       BR1S00001OM      BR1           Sales
# ...             ...      ...             ...
# 14785  WC2RS00008OM     WC2R           Sales
# 14786  WC2RS00009OM     WC2R           Sales
# 14787  WC2RS00010OM     WC2R           Sales
# 14788  WC2RS00011OM     WC2R           Sales
# 14789  WC2RS00012OM     WC2R           Sales
#
#                                 Property_Type
# 0           3 bedroom terraced house for sale  \
# 1           2 bedroom terraced house for sale
# 2      3 bedroom semi-detached house for sale
# 3           2 bedroom terraced house for sale
# 4                1 bedroom apartment for sale
# ...                                       ...
# 14785                 1 bedroom flat for sale
# ...

# %% [markdown]
# ### iii) Cleaning the Bedrooms column

# %%
# Checking the values counts
om.Bedrooms.value_counts()
# Out:
# Bedrooms
# 2             5188
# 3             3510
# 1             2843
# 4             1738
# 5              713
# 6              293
# Studio         272
# Not listed     107
# 7               72
# 8               27
# 9               10
# 10              10
# 15               3
# 11               2
# 17               1
# 12               1
# Name: count, dtype: int64

# %%
# Replacing the studios with not listed
om['Bedrooms'] = om['Bedrooms'].replace('Studio', 'Not listed')

# %%
# Checking the values counts
om.Bedrooms.value_counts()
# Out:
# Bedrooms
# 2             5188
# 3             3510
# 1             2843
# 4             1738
# 5              713
# Not listed     379
# 6              293
# 7               72
# 8               27
# 9               10
# 10              10
# 15               3
# 11               2
# 17               1
# 12               1
# Name: count, dtype: int64

# %% [markdown]
# Perfect!

# %% [markdown]
# # 3. Zoopla

# %% [markdown]
# Now we will clean the sales data for Zoopla

# %% [markdown]
# ## a) Data Accessment

# %%
zp.head()
# Out:
#      Unique_Id Location Tansaction_Type                      Property_Type
# 0  BR1S00001ZP      BR1           Sales  Bishops Avenue, Bromley, Kent BR1  \
# 1  BR1S00002ZP      BR1           Sales          College Road, Bromley BR1
# 2  BR1S00003ZP      BR1           Sales  Marian Gardens, Bromley, Kent BR1
# 3  BR1S00004ZP      BR1           Sales    Forde Avenue, Bromley, Kent BR1
# 4  BR1S00005ZP      BR1           Sales  Ellen Close, Bickley, Bromley BR1
#
#                               Address  Bedrooms  Bathrooms       Price
# 0  6 bed semi-detached house for sale         6          2  £1,250,000  \
# 1                 1 bed flat for sale         1          1    £255,000
# 2                 2 bed flat for sale         2          1    £550,000
# 3       3 bed terraced house for sale         3          1    £600,000
# 4  3 bed semi-detached house for sale         3          2    £525,000
#
#                                          Description             Listing_Date
# ...

# %%
# Checking the shape of the Dataset
zp.shape
# Out:
# (49494, 13)

# %%
# Checking the data types
zp.dtypes
# Out:
# Unique_Id          object
# Location           object
# Tansaction_Type    object
# Property_Type      object
# Address            object
# Bedrooms            int64
# Bathrooms           int64
# Price              object
# Description        object
# Listing_Date       object
# Agent              object
# Listing_Source     object
# listing_URL        object
# dtype: object

# %%
# Cheching the distribution of values
zp.describe()
# Out:
#            Bedrooms     Bathrooms
# count  49494.000000  49494.000000
# mean       2.441367      1.305653
# std        1.316987      0.675686
# min        1.000000      1.000000
# 25%        2.000000      1.000000
# 50%        2.000000      1.000000
# 75%        3.000000      1.000000
# max       33.000000     18.000000

# %% [markdown]
# ## b) Dealing with nulls

# %%
zp.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        0
# Listing_Date       0
# Agent              0
# Listing_Source     0
# listing_URL        0
# dtype: int64

# %% [markdown]
# There are no nulls in the dataset. Perfect!!!

# %% [markdown]
# ## c) Data cleaning

# %%
zp.head()
# Out:
#      Unique_Id Location Tansaction_Type                      Property_Type
# 0  BR1S00001ZP      BR1           Sales  Bishops Avenue, Bromley, Kent BR1  \
# 1  BR1S00002ZP      BR1           Sales          College Road, Bromley BR1
# 2  BR1S00003ZP      BR1           Sales  Marian Gardens, Bromley, Kent BR1
# 3  BR1S00004ZP      BR1           Sales    Forde Avenue, Bromley, Kent BR1
# 4  BR1S00005ZP      BR1           Sales  Ellen Close, Bickley, Bromley BR1
#
#                               Address  Bedrooms  Bathrooms       Price
# 0  6 bed semi-detached house for sale         6          2  £1,250,000  \
# 1                 1 bed flat for sale         1          1    £255,000
# 2                 2 bed flat for sale         2          1    £550,000
# 3       3 bed terraced house for sale         3          1    £600,000
# 4  3 bed semi-detached house for sale         3          2    £525,000
#
#                                          Description             Listing_Date
# ...

# %% [markdown]
# ### i) Cleaning the Listing_Date column

# %% [markdown]
# We will attempt to clean the Listing_Date to remove the 'Listed on' string attached to the listed date

# %%
# Strip "Listed on" from Date values while preserving 
zp['Listing_Date'] = zp['Listing_Date'].str.replace('Listed on', '').str.strip()

# %%
zp.head()
# Out:
#      Unique_Id Location Tansaction_Type                      Property_Type
# 0  BR1S00001ZP      BR1           Sales  Bishops Avenue, Bromley, Kent BR1  \
# 1  BR1S00002ZP      BR1           Sales          College Road, Bromley BR1
# 2  BR1S00003ZP      BR1           Sales  Marian Gardens, Bromley, Kent BR1
# 3  BR1S00004ZP      BR1           Sales    Forde Avenue, Bromley, Kent BR1
# 4  BR1S00005ZP      BR1           Sales  Ellen Close, Bickley, Bromley BR1
#
#                               Address  Bedrooms  Bathrooms       Price
# 0  6 bed semi-detached house for sale         6          2  £1,250,000  \
# 1                 1 bed flat for sale         1          1    £255,000
# 2                 2 bed flat for sale         2          1    £550,000
# 3       3 bed terraced house for sale         3          1    £600,000
# 4  3 bed semi-detached house for sale         3          2    £525,000
#
#                                          Description   Listing_Date
# ...

# %% [markdown]
# Now, we will convert the Listing dates into the format dd/mm/yyyy, for uniformity with the other datasets

# %%
# Convert the date format to 'dd/mm/yyyy'
zp['Listing_Date'] = zp['Listing_Date'].str.replace('th', '').str.replace('st', '').str.replace('nd', '').str.replace('rd', '').str.replace(' ', '/')

# Convert the month name to the month number
try: 
    zp['Listing_Date'] = pd.to_datetime(zp['Listing_Date'], format='%d/%B/%Y').dt.strftime('%d/%m/%Y')
except ValueError:
    pass

# Convert the month name to the month number
try: 
    # Update the month name to month number conversion
    zp['Listing_Date'] = zp['Listing_Date'].str.replace('/Jan/', '/01/').str.replace('/Feb/', '/02/').str.replace('/Mar/', '/03/').str.replace('/Apr/', '/04/').str.replace('/May/', '/05/').str.replace('/Jun/', '/06/').str.replace('/Jul/', '/07/').str.replace('/Aug/', '/08/').str.replace('/Sep/', '/09/').str.replace('/Oct/', '/10/').str.replace('/Nov/', '/11/').str.replace('/Dec/', '/12/')
except ValueError:
    pass

# %% [markdown]
# Convert any non-date values in the Listed_Date column to 'Not Listed'

# %%
# Convert the column to string type
zp['Listing_Date'] = zp['Listing_Date'].astype(str)

# Check if the value matches the date format
mask = zp['Listing_Date'].str.match(r'\d{2}/\d{2}/\d{4}')

# Replace non-matching values with 'Not Listed'
zp.loc[~mask, 'Listing_Date'] = 'Not Listed'

# %%
zp.head()
# Out:
#      Unique_Id Location Tansaction_Type                      Property_Type
# 0  BR1S00001ZP      BR1           Sales  Bishops Avenue, Bromley, Kent BR1  \
# 1  BR1S00002ZP      BR1           Sales          College Road, Bromley BR1
# 2  BR1S00003ZP      BR1           Sales  Marian Gardens, Bromley, Kent BR1
# 3  BR1S00004ZP      BR1           Sales    Forde Avenue, Bromley, Kent BR1
# 4  BR1S00005ZP      BR1           Sales  Ellen Close, Bickley, Bromley BR1
#
#                               Address  Bedrooms  Bathrooms       Price
# 0  6 bed semi-detached house for sale         6          2  £1,250,000  \
# 1                 1 bed flat for sale         1          1    £255,000
# 2                 2 bed flat for sale         2          1    £550,000
# 3       3 bed terraced house for sale         3          1    £600,000
# 4  3 bed semi-detached house for sale         3          2    £525,000
#
#                                          Description Listing_Date
# ...

# %% [markdown]
# Looks great!

# %% [markdown]
# <h1 style='background-color: Indigo; padding: 10px; color: white'> Rent data </h1>

# %% [markdown]
# We will import the rent data for the three websites

# %%
# Rightmove
rm1 = pd.read_csv('rightmove_rent_data.csv')

# On the Market
om1 = pd.read_csv('OnTheMarket_rent_data.csv')

#Zoopla
zp1 = pd.read_csv('Zoopla_rent-data.csv')

# %% [markdown]
# We will remove the unwanted column 'Unnamed from all the datasets'

# %%
# Rightmove
rm1 = rm1.drop('Unnamed: 0', axis=1)

# On the Market
om1 = om1.drop('Unnamed: 0', axis=1)

#Zoopla
zp1 = zp1.drop('Unnamed: 0', axis=1)

# %% [markdown]
# # Rightmove

# %% [markdown]
# Now we will assess and clean the rent data for rightmove

# %% [markdown]
# ## a) Data Assesment

# %%
rm1.head()
# Out:
#    Unique_Id Location Tansaction_Type   Property_Type
# 0  BR1R00001      BR1            Rent        Terraced  \
# 1  BR1R00002      BR1            Rent  End of Terrace
# 2  BR1R00003      BR1            Rent            Flat
# 3  BR1R00004      BR1            Rent          Studio
# 4  BR1R00005      BR1            Rent            Flat
#
#                                              Address  Bedrooms  Bathrooms
# 0                       Hillcrest Road, Bromley, BR1         3          1  \
# 1                         Pendragon Road Bromley BR1         5          2
# 2                             Hillside, Bickley, BR1         2          1
# 3  **ALL BILLS INCLUDED** Coniston Road, Bromley,...         1          1
# 4                           Dale Court, Bromley, BR1         3          1
#
#         Price                                        Description
# 0  £2,000 pcm  We are delighted to present to the market this...  \
# ...

# %%
# Checking the shape of the data
rm1.shape
# Out:
# (21126, 13)

# %%
# Checking the distribution of values
rm1.describe()
# Out:
#            Bedrooms     Bathrooms
# count  21126.000000  21126.000000
# mean       2.147259      1.712203
# std        1.171554      0.935005
# min        1.000000      1.000000
# 25%        1.000000      1.000000
# 50%        2.000000      2.000000
# 75%        3.000000      2.000000
# max       20.000000     12.000000

# %%
# Assessing the data types
rm1.dtypes
# Out:
# Unique_Id          object
# Location           object
# Tansaction_Type    object
# Property_Type      object
# Address            object
# Bedrooms            int64
# Bathrooms           int64
# Price              object
# Description        object
# Listing_Date       object
# Agent              object
# Listing_Source     object
# listing_URL        object
# dtype: object

# %% [markdown]
# ## b) Dealing with nulls

# %%
rm1.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        0
# Listing_Date       7
# Agent              0
# Listing_Source     0
# listing_URL        0
# dtype: int64

# %% [markdown]
# Only the Listing_Date column has nulls

# %% [markdown]
# ### i) Dealing with nulls in the Listing_Date column

# %% [markdown]
# We will replace the nulls with 'Not Listed'

# %%
rm1['Listing_Date'].fillna('Not listed', inplace=True)

# %%
rm1.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        0
# Listing_Date       0
# Agent              0
# Listing_Source     0
# listing_URL        0
# dtype: int64

# %% [markdown]
# Nulls succesfully dealth with

# %% [markdown]
# ## c) Data Cleaning

# %%
rm1.head()
# Out:
#    Unique_Id Location Tansaction_Type   Property_Type
# 0  BR1R00001      BR1            Rent        Terraced  \
# 1  BR1R00002      BR1            Rent  End of Terrace
# 2  BR1R00003      BR1            Rent            Flat
# 3  BR1R00004      BR1            Rent          Studio
# 4  BR1R00005      BR1            Rent            Flat
#
#                                              Address  Bedrooms  Bathrooms
# 0                       Hillcrest Road, Bromley, BR1         3          1  \
# 1                         Pendragon Road Bromley BR1         5          2
# 2                             Hillside, Bickley, BR1         2          1
# 3  **ALL BILLS INCLUDED** Coniston Road, Bromley,...         1          1
# 4                           Dale Court, Bromley, BR1         3          1
#
#         Price                                        Description
# 0  £2,000 pcm  We are delighted to present to the market this...  \
# ...

# %% [markdown]
# Now, we will modify the Listed date column

# %%
# Removing the 'Added on' from the values
rm1['Listing_Date'] = rm1['Listing_Date'].str.replace('Added on ', '', regex=True)
rm1['Listing_Date'] = rm1['Listing_Date'].str.replace('Reduced on ', '', regex=True)

# %% [markdown]
# Convert any non-date values in the Listed_Date column to 'Not Listed'

# %%
# Convert the column to string type
rm1['Listing_Date'] = rm1['Listing_Date'].astype(str)

# Check if the value matches the date format
mask = rm1['Listing_Date'].str.match(r'\d{2}/\d{2}/\d{4}')

# Replace non-matching values with 'Not Listed'
rm1.loc[~mask, 'Listing_Date'] = 'Not Listed'

# %%
rm1.head()
# Out:
#    Unique_Id Location Tansaction_Type   Property_Type
# 0  BR1R00001      BR1            Rent        Terraced  \
# 1  BR1R00002      BR1            Rent  End of Terrace
# 2  BR1R00003      BR1            Rent            Flat
# 3  BR1R00004      BR1            Rent          Studio
# 4  BR1R00005      BR1            Rent            Flat
#
#                                              Address  Bedrooms  Bathrooms
# 0                       Hillcrest Road, Bromley, BR1         3          1  \
# 1                         Pendragon Road Bromley BR1         5          2
# 2                             Hillside, Bickley, BR1         2          1
# 3  **ALL BILLS INCLUDED** Coniston Road, Bromley,...         1          1
# 4                           Dale Court, Bromley, BR1         3          1
#
#         Price                                        Description Listing_Date
# 0  £2,000 pcm  We are delighted to present to the market this...   04/05/2023  \
# ...

# %% [markdown]
# ### ii) Cleaning the Agent column

# %% [markdown]
# Modifying the Agent column

# %%
# Removing all strings before the word 'by'
try:
    rm1['Agent'] = rm1['Agent'].str.split('by', n=1).str[1].str.strip()
except ValueError:
    pass

# %%
# Replace all nulls with 'Not listed'
rm1['Agent'].fillna('Not listed', inplace=True)

# %%
rm1.head()
# Out:
#    Unique_Id Location Tansaction_Type   Property_Type
# 0  BR1R00001      BR1            Rent        Terraced  \
# 1  BR1R00002      BR1            Rent  End of Terrace
# 2  BR1R00003      BR1            Rent            Flat
# 3  BR1R00004      BR1            Rent          Studio
# 4  BR1R00005      BR1            Rent            Flat
#
#                                              Address  Bedrooms  Bathrooms
# 0                       Hillcrest Road, Bromley, BR1         3          1  \
# 1                         Pendragon Road Bromley BR1         5          2
# 2                             Hillside, Bickley, BR1         2          1
# 3  **ALL BILLS INCLUDED** Coniston Road, Bromley,...         1          1
# 4                           Dale Court, Bromley, BR1         3          1
#
#         Price                                        Description Listing_Date
# 0  £2,000 pcm  We are delighted to present to the market this...   04/05/2023  \
# ...

# %% [markdown]
# Looks great!!!

# %% [markdown]
# # On the Market

# %% [markdown]
# Now we will clean the rent data for On the Market

# %% [markdown]
# ## a) Data Assessment

# %%
om1.head()
# Out:
#      Unique_Id Location Tansaction_Type                Property_Type
# 0  BR1S00001OM      BR1            Rent  2 bedroom apartment to rent  \
# 1  BR1S00002OM      BR1            Rent  2 bedroom apartment to rent
# 2  BR1S00003OM      BR1            Rent      5 bedroom house to rent
# 3  BR1S00004OM      BR1            Rent               Studio to rent
# 4  BR1S00005OM      BR1            Rent       2 bedroom flat to rent
#
#                                          Address Bedrooms Bathrooms
# 0                          Park Hill Bickley BR1        2         1  \
# 1                       237 Downham Way, Bromley        2         1
# 2  Edgeborough Way, Sundridge Park, Bromley, BR1        5         2
# 3                       Bromley Hill, London BR1   Studio         1
# 4                     Widmore Road, Bromley, BR1        2         2
#
#                   Price                                        Description
# ...

# %%
# Checking the shape of the Dataset
om1.shape
# Out:
# (22516, 14)

# %%
# Checking the datatype
om1.dtypes
# Out:
# Unique_Id          object
# Location           object
# Tansaction_Type    object
# Property_Type      object
# Address            object
# Bedrooms           object
# Bathrooms          object
# Price              object
# Description        object
# Listing_Date       object
# Agent              object
# Listing_Source     object
# listing_URL        object
# Current_date       object
# dtype: object

# %% [markdown]
# ## b) Dealing with nulls

# %%
om1.isnull().sum()
# Out:
# Unique_Id             0
# Location              0
# Tansaction_Type       0
# Property_Type         0
# Address               0
# Bedrooms            647
# Bathrooms          1806
# Price                 3
# Description           0
# Listing_Date          0
# Agent               103
# Listing_Source        0
# listing_URL           0
# Current_date          0
# dtype: int64

# %% [markdown]
# Now, we will replace all the nulls with 'Not listed'

# %%
# Replacing nulls in the Bedroom column with 'Not Listed'
om1['Bedrooms'].fillna('Not listed', inplace=True)

# Replacing nulls in the Bathrooms column with 'Not Listed'
om1['Bathrooms'].fillna('Not listed', inplace=True)

# Replacing nulls in the Agent column with 'Not Listed'
om1['Agent'].fillna('Not listed', inplace=True)

# Replacing nulls in the Price column with 'Not Listed'
om1['Price'].fillna('Not listed', inplace=True)

# %%
om1.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        0
# Listing_Date       0
# Agent              0
# Listing_Source     0
# listing_URL        0
# Current_date       0
# dtype: int64

# %% [markdown]
# Great!!!

# %% [markdown]
# ## c) Data Cleaning

# %% [markdown]
# ### i) Cleaning the Listing_Date Column

# %% [markdown]
# Here are the values available in the Listing_Date

# %%
om1.Listing_Date.value_counts()
# Out:
# Listing_Date
# OnTheMarket > 14 days    14253
# OnTheMarket < 7 days      3439
# OnTheMarket < 14 days     2496
# Reduced < 7 days           701
# Reduced < 14 days          583
# OnTheMarket today          439
# OnTheMarket yesterday      385
# Reduced today              112
# Reduced yesterday           75
# Reduced > 14 days           32
# Listing_Date                 1
# Name: count, dtype: int64

# %% [markdown]
# We will repeat the same process as we did with the On the market sales data

# %%
# Convert 'Current_date' column to datetime type
om1['Current_date'] = pd.to_datetime(om1['Current_date'], format='%d/%m/%Y')

# Calculate the new 'Date_main' column based on different conditions
om1['Date_main'] = om1.apply(
    lambda row: (
        (row['Current_date']).strftime('%d/%m/%Y')
        if row['Listing_Date'] in ['Reduced today', 'OnTheMarket today']
        else (row['Current_date'] - timedelta(days=1)).strftime('%d/%m/%Y')
        if row['Listing_Date'] in ['Reduced yesterday', 'OnTheMarket yesterday']
        else (row['Current_date'] - timedelta(days=14)).strftime('%d/%m/%Y')  # > (current date - 14 days)
        if row['Listing_Date'] in ['OnTheMarket > 14 days', 'Reduced > 14 days']
        else (row['Current_date'] - timedelta(days=14)).strftime('%d/%m/%Y')  # < (current date - 14 days)
        if row['Listing_Date'] in ['OnTheMarket < 14 days', 'Reduced < 14 days']
        else (row['Current_date'] - timedelta(days=7)).strftime('%d/%m/%Y')  # < (current date - 7 days)
        if row['Listing_Date'] in ['OnTheMarket < 7 days', 'Reduced < 7 days']
        else None  # Add any other conditions or default value if needed
    ),
    axis=1
)

# Convert the column to datetime type
om1['Date_main'] = pd.to_datetime(om1['Date_main'], format='%d/%m/%Y')

# Convert the values to the desired format
om1['Date_main'] = om1['Date_main'].dt.strftime('%d/%m/%Y')

# %%
om1.head()
# Out:
#      Unique_Id Location Tansaction_Type                Property_Type
# 0  BR1S00001OM      BR1            Rent  2 bedroom apartment to rent  \
# 1  BR1S00002OM      BR1            Rent  2 bedroom apartment to rent
# 2  BR1S00003OM      BR1            Rent      5 bedroom house to rent
# 3  BR1S00004OM      BR1            Rent               Studio to rent
# 4  BR1S00005OM      BR1            Rent       2 bedroom flat to rent
#
#                                          Address Bedrooms Bathrooms
# 0                          Park Hill Bickley BR1        2         1  \
# 1                       237 Downham Way, Bromley        2         1
# 2  Edgeborough Way, Sundridge Park, Bromley, BR1        5         2
# 3                       Bromley Hill, London BR1   Studio         1
# 4                     Widmore Road, Bromley, BR1        2         2
#
#                   Price                                        Description
# ...

# %%
om1.shape
# Out:
# (22516, 15)

# %%
# Drop the 'Current_date' and 'Listing_Date' columns
om1.drop(['Current_date', 'Listing_Date'], axis=1, inplace=True)

# %% [markdown]
# For uniformity with the datsets from other websites, the Date_main column will be renamed as Listing_Date

# %%
# Rename the 'Date_main' column to 'Listing_Date'
om1.rename(columns={'Date_main': 'Listing_Date'}, inplace=True)

# %%
om1.head()
# Out:
#      Unique_Id Location Tansaction_Type                Property_Type
# 0  BR1S00001OM      BR1            Rent  2 bedroom apartment to rent  \
# 1  BR1S00002OM      BR1            Rent  2 bedroom apartment to rent
# 2  BR1S00003OM      BR1            Rent      5 bedroom house to rent
# 3  BR1S00004OM      BR1            Rent               Studio to rent
# 4  BR1S00005OM      BR1            Rent       2 bedroom flat to rent
#
#                                          Address Bedrooms Bathrooms
# 0                          Park Hill Bickley BR1        2         1  \
# 1                       237 Downham Way, Bromley        2         1
# 2  Edgeborough Way, Sundridge Park, Bromley, BR1        5         2
# 3                       Bromley Hill, London BR1   Studio         1
# 4                     Widmore Road, Bromley, BR1        2         2
#
#                   Price                                        Description
# ...

# %% [markdown]
# Now we will move the new listed date column to it's right position

# %%
# Get the column names
columns = om1.columns.tolist()

# Specify the position where you want to move the column (e.g., from 4th position to 1st position)
from_position = 12
to_position = 9

# Move the column to the desired position
columns.insert(to_position, columns.pop(from_position))

# Reassign the columns in the DataFrame with the updated order
om1 = om1[columns]

# %%
om1.head()
# Out:
#      Unique_Id Location Tansaction_Type                Property_Type
# 0  BR1S00001OM      BR1            Rent  2 bedroom apartment to rent  \
# 1  BR1S00002OM      BR1            Rent  2 bedroom apartment to rent
# 2  BR1S00003OM      BR1            Rent      5 bedroom house to rent
# 3  BR1S00004OM      BR1            Rent               Studio to rent
# 4  BR1S00005OM      BR1            Rent       2 bedroom flat to rent
#
#                                          Address Bedrooms Bathrooms
# 0                          Park Hill Bickley BR1        2         1  \
# 1                       237 Downham Way, Bromley        2         1
# 2  Edgeborough Way, Sundridge Park, Bromley, BR1        5         2
# 3                       Bromley Hill, London BR1   Studio         1
# 4                     Widmore Road, Bromley, BR1        2         2
#
#                   Price                                        Description
# ...

# %% [markdown]
# ### ii) Cleaning the Bathrooms column

# %%
# Strip ".0" from float values while preserving "Not Listed"
om1['Bathrooms'] = om1['Bathrooms'].apply(lambda x: str(x).rstrip('.0') if x != 'Not Listed' else x)

# %%
om1.head()
# Out:
#      Unique_Id Location Tansaction_Type                Property_Type
# 0  BR1S00001OM      BR1            Rent  2 bedroom apartment to rent  \
# 1  BR1S00002OM      BR1            Rent  2 bedroom apartment to rent
# 2  BR1S00003OM      BR1            Rent      5 bedroom house to rent
# 3  BR1S00004OM      BR1            Rent               Studio to rent
# 4  BR1S00005OM      BR1            Rent       2 bedroom flat to rent
#
#                                          Address Bedrooms Bathrooms
# 0                          Park Hill Bickley BR1        2         1  \
# 1                       237 Downham Way, Bromley        2         1
# 2  Edgeborough Way, Sundridge Park, Bromley, BR1        5         2
# 3                       Bromley Hill, London BR1   Studio         1
# 4                     Widmore Road, Bromley, BR1        2         2
#
#                   Price                                        Description
# ...

# %% [markdown]
# ### iii) Cleaning the Bedrooms column

# %%
# Checking the values counts
om1.Bedrooms.value_counts()
# Out:
# Bedrooms
# 2             8014
# 1             5508
# 3             3924
# Studio        1910
# 4             1390
# 5              749
# Not listed     647
# 6              243
# 7               92
# 8               24
# 10               9
# 11               3
# 12               1
# Bedrooms         1
# 9                1
# Name: count, dtype: int64

# %%
# Replacing the studios with not listed
om1['Bedrooms'] = om1['Bedrooms'].replace('Studio', 'Not listed')
om1['Bedrooms'] = om1['Bedrooms'].replace('Bedrooms', 'Not listed')

# %%
# Checking the values counts
om1.Bedrooms.value_counts()
# Out:
# Bedrooms
# 2             8014
# 1             5508
# 3             3924
# Not listed    2558
# 4             1390
# 5              749
# 6              243
# 7               92
# 8               24
# 10               9
# 11               3
# 12               1
# 9                1
# Name: count, dtype: int64

# %% [markdown]
# # 3. Zoopla

# %% [markdown]
# Now we will clean the sales data for Zoopla

# %% [markdown]
# ## a) Data Assessment

# %%
zp1.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1R00001ZP      BR1            Rent  \
# 1  BR1R00002ZP      BR1            Rent
# 2  BR1R00003ZP      BR1            Rent
# 3  BR1R00004ZP      BR1            Rent
# 4  BR1R00005ZP      BR1            Rent
#
#                               Property_Type                   Address
# 0                    Park Road, Bromley BR1  1 bed maisonette to rent  \
# 1                Highland Road, Bromley BR1        3 bed flat to rent
# 2                  Downham Way, Bromley BR1        2 bed flat to rent
# 3            Downham Way, Bromley, Kent BR1        2 bed flat to rent
# 4  Downham Way, Bromley, Greater London BR1        2 bed flat to rent
#
#    Bedrooms  Bathrooms       Price
# 0         1          1  £1,450 pcm  \
# 1         3          1  £2,250 pcm
# 2         2          1  £1,700 pcm
# 3         2          1  £1,300 pcm
# 4         2          1  £1,250 pcm
#
#                                          Description
# ...

# %%
# Checking the shape
zp1.shape
# Out:
# (21873, 13)

# %%
# Checking the distribution of values
zp1.describe()
# Out:
#            Bedrooms     Bathrooms
# count  21873.000000  21873.000000
# mean       2.105655      1.136744
# std        1.161534      0.475439
# min        1.000000      1.000000
# 25%        1.000000      1.000000
# 50%        2.000000      1.000000
# 75%        3.000000      1.000000
# max       13.000000      9.000000

# %% [markdown]
# ## b) Dealing with nulls

# %%
zp1.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        1
# Listing_Date       0
# Agent              0
# Listing_Source     0
# listing_URL        0
# dtype: int64

# %% [markdown]
# We will replace the null in the description column with 'Not listed'

# %%
zp1['Description'].fillna('Not listed', inplace=True)

# %%
zp1.isnull().sum()
# Out:
# Unique_Id          0
# Location           0
# Tansaction_Type    0
# Property_Type      0
# Address            0
# Bedrooms           0
# Bathrooms          0
# Price              0
# Description        0
# Listing_Date       0
# Agent              0
# Listing_Source     0
# listing_URL        0
# dtype: int64

# %% [markdown]
# ## c) Data cleaning

# %%
zp1.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1R00001ZP      BR1            Rent  \
# 1  BR1R00002ZP      BR1            Rent
# 2  BR1R00003ZP      BR1            Rent
# 3  BR1R00004ZP      BR1            Rent
# 4  BR1R00005ZP      BR1            Rent
#
#                               Property_Type                   Address
# 0                    Park Road, Bromley BR1  1 bed maisonette to rent  \
# 1                Highland Road, Bromley BR1        3 bed flat to rent
# 2                  Downham Way, Bromley BR1        2 bed flat to rent
# 3            Downham Way, Bromley, Kent BR1        2 bed flat to rent
# 4  Downham Way, Bromley, Greater London BR1        2 bed flat to rent
#
#    Bedrooms  Bathrooms       Price
# 0         1          1  £1,450 pcm  \
# 1         3          1  £2,250 pcm
# 2         2          1  £1,700 pcm
# 3         2          1  £1,300 pcm
# 4         2          1  £1,250 pcm
#
#                                          Description
# ...

# %% [markdown]
# ### i) Cleaning the Listing_Date column

# %% [markdown]
# We will attempt to clean the Listing_Date to remove the 'Listed on' string attached to the listed date

# %%
# Strip "Listed on" from Date values while preserving 
zp1['Listing_Date'] = zp1['Listing_Date'].str.replace('Listed on', '').str.strip()
zp1['Listing_Date'] = zp1['Listing_Date'].str.replace('Available from', '').str.strip()

# %%
zp1.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1R00001ZP      BR1            Rent  \
# 1  BR1R00002ZP      BR1            Rent
# 2  BR1R00003ZP      BR1            Rent
# 3  BR1R00004ZP      BR1            Rent
# 4  BR1R00005ZP      BR1            Rent
#
#                               Property_Type                   Address
# 0                    Park Road, Bromley BR1  1 bed maisonette to rent  \
# 1                Highland Road, Bromley BR1        3 bed flat to rent
# 2                  Downham Way, Bromley BR1        2 bed flat to rent
# 3            Downham Way, Bromley, Kent BR1        2 bed flat to rent
# 4  Downham Way, Bromley, Greater London BR1        2 bed flat to rent
#
#    Bedrooms  Bathrooms       Price
# 0         1          1  £1,450 pcm  \
# 1         3          1  £2,250 pcm
# 2         2          1  £1,700 pcm
# 3         2          1  £1,300 pcm
# 4         2          1  £1,250 pcm
#
#                                          Description   Listing_Date
# ...

# %% [markdown]
# Now, we will convert the Listing dates into the format dd/mm/yyyy, for uniformity with the other datasets

# %%
# Convert the date format to 'dd/mm/yyyy'
zp1['Listing_Date'] = zp1['Listing_Date'].str.replace('th', '').str.replace('st', '').str.replace('nd', '').str.replace('rd', '').str.replace(' ', '/')

# Convert the month name to the month number
try: 
    zp1['Listing_Date'] = pd.to_datetime(zp1['Listing_Date'], format='%d/%B/%Y').dt.strftime('%d/%m/%Y')
except ValueError:
    pass

# Convert the month name to the month number
try: 
    # Update the month name to month number conversion
    zp1['Listing_Date'] = zp1['Listing_Date'].str.replace('/Jan/', '/01/').str.replace('/Feb/', '/02/').str.replace('/Mar/', '/03/').str.replace('/Apr/', '/04/').str.replace('/May/', '/05/').str.replace('/Jun/', '/06/').str.replace('/Jul/', '/07/').str.replace('/Aug/', '/08/').str.replace('/Sep/', '/09/').str.replace('/Oct/', '/10/').str.replace('/Nov/', '/11/').str.replace('/Dec/', '/12/')
except ValueError:
    pass

# %%
zp1.head()
# Out:
#      Unique_Id Location Tansaction_Type
# 0  BR1R00001ZP      BR1            Rent  \
# 1  BR1R00002ZP      BR1            Rent
# 2  BR1R00003ZP      BR1            Rent
# 3  BR1R00004ZP      BR1            Rent
# 4  BR1R00005ZP      BR1            Rent
#
#                               Property_Type                   Address
# 0                    Park Road, Bromley BR1  1 bed maisonette to rent  \
# 1                Highland Road, Bromley BR1        3 bed flat to rent
# 2                  Downham Way, Bromley BR1        2 bed flat to rent
# 3            Downham Way, Bromley, Kent BR1        2 bed flat to rent
# 4  Downham Way, Bromley, Greater London BR1        2 bed flat to rent
#
#    Bedrooms  Bathrooms       Price
# 0         1          1  £1,450 pcm  \
# 1         3          1  £2,250 pcm
# 2         2          1  £1,700 pcm
# 3         2          1  £1,300 pcm
# 4         2          1  £1,250 pcm
#
#                                          Description Listing_Date
# ...

# %% [markdown]
# Convert any non-date values in the Listed_Date column to 'Not Listed'

# %%
# Convert the column to string type
zp1['Listing_Date'] = zp1['Listing_Date'].astype(str)

# Check if the value matches the date format
mask = zp1['Listing_Date'].str.match(r'\d{2}/\d{2}/\d{4}')

# Replace non-matching values with 'Not Listed'
zp1.loc[~mask, 'Listing_Date'] = 'Not Listed'

# %%
zp1.Listing_Date.value_counts()
# Out:
# Listing_Date
# Not Listed    8722
# 23/05/2023     877
# 22/05/2023     757
# 18/05/2023     501
# 17/05/2023     487
#               ...
# 17/05/2024       1
# 28/06/2024       1
# 18/05/2024       1
# 21/01/2023       1
# 18/07/2022       1
# Name: count, Length: 467, dtype: int64

# %% [markdown]
# Great.

# %% [markdown]
# <h1 style='background-color: Indigo; padding: 10px; color: white; text-align: center;'>DATA MERGING </h1>

# %% [markdown]
# Here, we will merge the three dataset for sales and rent properties separately before combining them into a master dataset

# %% [markdown]
# <h1 style='background-color: Indigo; padding: 10px; color: white'> Sales data </h1>

# %%
# Checking the shape of the three sales dataset
rm.shape, om.shape, zp.shape
# Out:
# ((49641, 13), (14790, 13), (49494, 13))

# %%
# Total number of available columns
rm.shape[0] + om.shape[0]+ zp.shape[0]
# Out:
# 113925

# %% [markdown]
# The total number of available properties is 113,925

# %% [markdown]
# We will now merge the three datasets and eliminate any duplicate entries. We will identify duplicates based on the following columns: 'Location', 'Transaction_Type', 'Property_Type', 'Address', 'Bedrooms', 'Bathrooms', 'Price', 'Description', and 'Agent'.
#
# We will exclude the 'unique_id', 'listing_source', and 'source_url' columns from the duplicate check as these features are specific to each website.

# %%
# Concatenate the datasets vertically
merged = pd.concat([rm, om, zp], ignore_index=True)


# Specify the columns to check for duplicates
duplicate_cols = ['Location', 'Tansaction_Type', 'Property_Type', 'Address', 
                  'Bedrooms', 'Bathrooms', 'Price', 
                  'Description', 'Agent']

# Remove duplicates based on the specified columns
merged_sales = merged.drop_duplicates(subset=duplicate_cols)

# Reset the index of the merged DataFrame
merged_sales.reset_index(drop=True, inplace=True)

# %%
merged_sales.shape
# Out:
# (112978, 13)

# %% [markdown]
# After dropping the dublicates the number of available properties is 112,978 (947 Properties dropped)

# %%
# Saving to file
merged_sales.to_csv('sales_merged_test.csv')

# %% [markdown]
# <h1 style='background-color: Indigo; padding: 10px; color: white'> Rent data </h1>

# %%
# Checking the shape of the three sales dataset
rm1.shape, om1.shape, zp1.shape
# Out:
# ((21126, 13), (22516, 13), (21873, 13))

# %%
# Total number of available columns
rm1.shape[0] + om1.shape[0]+ zp1.shape[0]
# Out:
# 65515

# %% [markdown]
# We will go through the same process lke we did with the sales data

# %%
# Concatenate the datasets vertically
merged = pd.concat([rm1, om1, zp1], ignore_index=True)


# Specify the columns to check for duplicates
duplicate_cols = ['Location', 'Tansaction_Type', 'Property_Type', 'Address', 
                  'Bedrooms', 'Bathrooms', 'Price', 
                  'Description', 'Agent']

# Remove duplicates based on the specified columns
merged_rent = merged.drop_duplicates(subset=duplicate_cols)

# Reset the index of the merged DataFrame
merged_rent.reset_index(drop=True, inplace=True)

# %%
merged_rent.shape
# Out:
# (62429, 13)

# %%
65515 -62429
# Out:
# 3086

# %% [markdown]
# After dropping the dublicates the number of available properties is 65,515 (3086 Properties dropped)

# %%
# Saving to file
merged_rent.to_csv('rent_merged_test.csv')
